# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import NearestNeighbors
import warnings
warnings.filterwarnings('ignore')

# %%
data  =  pd.read_csv("C:/Users/remis/Documents/M1/cine5/python/data/DATASETULTIME.csv")

# %%
def load_and_prepare_data(filepath):
    """
    Charge et prépare les données pour la recommandation.
    
    Args:
        filepath: Chemin vers le fichier CSV
        
    Returns:
        DataFrame avec les données nettoyées
    """
    data = pd.read_csv(filepath)
    
    # Remplir les valeurs manquantes
    data = data.fillna('')
    
    # S'assurer que Rating et Total_Gross sont numériques
    data['Rating'] = pd.to_numeric(data['Rating'], errors='coerce').fillna(0)
    data['Total_Gross'] = pd.to_numeric(data['Total_Gross'], errors='coerce').fillna(0)
    data['Runtime(Mins)'] = pd.to_numeric(data['Runtime(Mins)'], errors='coerce').fillna(0)
    data['Year'] = pd.to_numeric(data['Year'], errors='coerce').fillna(0)
    
    return data

# %%
def create_bag_of_words(data, include_plot=False, genre_weight=1):
    """
    Crée le bag of words pour chaque film.
    
    Args:
        data: DataFrame des films
        include_plot: Inclure le résumé du film
        genre_weight: Nombre de répétitions pour renforcer l'importance des genres
        
    Returns:
        Series contenant le bag of words pour chaque film
    """
    bag = (
        data["Movie_Title"].astype(str) + " " +
        data["Director"].astype(str) + " " +
        data["Actors"].astype(str) + " " +
        (data["main_genre"].astype(str) + " ") * genre_weight +
        (data["side_genre"].astype(str) + " ") * max(1, genre_weight - 1)
    )
    
    if include_plot:
        bag = bag + " " + data["plot"].astype(str)
    
    return bag

# %%
def normalize_feature(values):
    """
    Normalise un vecteur de valeurs entre 0 et 1.
    
    Args:
        values: Array numpy de valeurs
        
    Returns:
        Array numpy normalisé
    """
    v_min = values.min()
    v_max = values.max()
    if v_max - v_min == 0:
        return np.zeros_like(values)
    return (values - v_min) / (v_max - v_min)

# %%
def model_content_pure(query_idx, tfidf_matrix, data, top_k=5):
    """
    Modèle 1: Content-Based Pure (baseline)
    Utilise uniquement la similarité de contenu.
    
    Args:
        query_idx: Index du film requête
        tfidf_matrix: Matrice TF-IDF
        data: DataFrame des films
        top_k: Nombre de recommandations
        
    Returns:
        DataFrame des recommandations avec scores
    """
    query_vec = tfidf_matrix[query_idx]
    sims = cosine_similarity(query_vec, tfidf_matrix)[0]
    
    # Score = similarité uniquement
    scores = sims
    
    return _get_top_recommendations(query_idx, scores, sims, data, top_k)

# %%
def model_hybrid_rating(query_idx, tfidf_matrix, data, top_k=5, alpha=0.2):
    """
    Modèle 2: Hybrid Content + Rating
    Combine similarité de contenu et rating.
    
    Args:
        query_idx: Index du film requête
        tfidf_matrix: Matrice TF-IDF
        data: DataFrame des films
        top_k: Nombre de recommandations
        alpha: Poids du rating (0.2 = 20%)
        
    Returns:
        DataFrame des recommandations avec scores
    """
    query_vec = tfidf_matrix[query_idx]
    sims = cosine_similarity(query_vec, tfidf_matrix)[0]
    
    # Normaliser les ratings
    ratings = data["Rating"].to_numpy()
    rating_norm = normalize_feature(ratings)
    
    # Score hybride
    scores = (1 - alpha) * sims + alpha * rating_norm
    
    return _get_top_recommendations(query_idx, scores, sims, data, top_k)

# %%
def model_hybrid_full(query_idx, tfidf_matrix, data, top_k=5, alpha=0.2, beta=0.1):
    """
    Modèle 3: Hybrid Content + Rating + Box Office
    Combine similarité, rating et popularité (box office).
    
    Args:
        query_idx: Index du film requête
        tfidf_matrix: Matrice TF-IDF
        data: DataFrame des films
        top_k: Nombre de recommandations
        alpha: Poids du rating (0.2 = 20%)
        beta: Poids du box office (0.1 = 10%)
        
    Returns:
        DataFrame des recommandations avec scores
    """
    query_vec = tfidf_matrix[query_idx]
    sims = cosine_similarity(query_vec, tfidf_matrix)[0]
    
    # Normaliser ratings et box office
    ratings = data["Rating"].to_numpy()
    rating_norm = normalize_feature(ratings)
    
    box_office = data["Total_Gross"].to_numpy()
    box_office_norm = normalize_feature(box_office)
    
    # Score hybride complet
    scores = (1 - alpha - beta) * sims + alpha * rating_norm + beta * box_office_norm
    
    return _get_top_recommendations(query_idx, scores, sims, data, top_k)

# %%
def model_knn(query_idx, data, top_k=5):
    """
    Modèle 4: K-Nearest Neighbors
    Utilise toutes les features numériques et catégorielles encodées.
    
    Args:
        query_idx: Index du film requête
        data: DataFrame des films
        top_k: Nombre de recommandations
        
    Returns:
        DataFrame des recommandations avec scores
    """
    # Préparer les features numériques
    features_numeric = data[['Year', 'Rating', 'Runtime(Mins)', 'Total_Gross']].copy()
    
    # One-hot encoding des genres
    main_genre_dummies = pd.get_dummies(data['main_genre'], prefix='main')
    side_genre_dummies = pd.get_dummies(data['side_genre'], prefix='side')
    
    # Combiner toutes les features
    features = pd.concat([features_numeric, main_genre_dummies, side_genre_dummies], axis=1)
    
    # Normaliser
    scaler = StandardScaler()
    features_scaled = scaler.fit_transform(features)
    
    # KNN
    knn = NearestNeighbors(n_neighbors=top_k+1, metric='euclidean')
    knn.fit(features_scaled)
    
    # Trouver les voisins
    distances, indices = knn.kneighbors([features_scaled[query_idx]])
    
    # Exclure le film lui-même
    indices = indices[0][1:]
    distances = distances[0][1:]
    
    # Convertir distances en scores de similarité (inverse)
    max_dist = distances.max() if distances.max() > 0 else 1
    sims = 1 - (distances / max_dist)
    
    # Créer le DataFrame de résultats
    recs = data.iloc[indices][["Movie_Title", "Year", "main_genre", "side_genre", "Rating", "Total_Gross"]].copy()
    recs["similarity"] = sims
    recs["score"] = sims
    
    return recs

# %%
def _get_top_recommendations(query_idx, scores, sims, data, top_k):
    """
    Fonction utilitaire pour extraire les top K recommandations.
    
    Args:
        query_idx: Index du film requête
        scores: Scores finaux
        sims: Scores de similarité
        data: DataFrame des films
        top_k: Nombre de recommandations
        
    Returns:
        DataFrame des recommandations
    """
    # Trier par score décroissant
    sorted_idx = np.argsort(scores)[::-1]
    
    # Filtrer pour exclure le film requête
    filtered_idx = [i for i in sorted_idx if i != query_idx][:top_k]
    
    # Créer le DataFrame de résultats
    recs = data.iloc[filtered_idx][["Movie_Title", "Year", "main_genre", "side_genre", "Rating", "Total_Gross"]].copy()
    recs["similarity"] = sims[filtered_idx]
    recs["score"] = scores[filtered_idx]
    
    return recs

# %%
def evaluate_recommendations(recs):
    """
    Évalue la qualité des recommandations selon plusieurs métriques.
    
    Args:
        recs: DataFrame des recommandations
        
    Returns:
        Dict contenant les métriques d'évaluation
    """
    metrics = {
        'avg_rating': recs['Rating'].mean(),
        'avg_similarity': recs['similarity'].mean(),
        'avg_score': recs['score'].mean(),
        'genre_diversity': len(recs['main_genre'].unique()),
        'year_std': recs['Year'].std(),
        'avg_box_office': recs['Total_Gross'].mean()
    }
    
    return metrics

# %%
def compare_models(data, test_indices, models_config):
    """
    Compare tous les modèles sur plusieurs films de test.
    
    Args:
        data: DataFrame des films
        test_indices: Liste des indices de films à tester
        models_config: Dict de configuration des modèles
        
    Returns:
        DataFrame comparatif des résultats
    """
    all_results = []
    
    for test_idx in test_indices:
        print(f"\n{'='*80}")
        print(f"FILM DE TEST: {data.iloc[test_idx]['Movie_Title']} ({data.iloc[test_idx]['Year']})")
        print(f"Genre: {data.iloc[test_idx]['main_genre']} | Rating: {data.iloc[test_idx]['Rating']}")
        print(f"{'='*80}\n")
        
        for model_name, config in models_config.items():
            print(f"--- {model_name} ---")
            
            # Obtenir les recommandations
            recs = config['function'](**config['params'])
            
            # Évaluer
            metrics = evaluate_recommendations(recs)
            metrics['model'] = model_name
            metrics['test_film'] = data.iloc[test_idx]['Movie_Title']
            metrics['test_idx'] = test_idx
            
            all_results.append(metrics)
            
            # Afficher les recommandations
            print(recs[['Movie_Title', 'Year', 'main_genre', 'Rating', 'score']].to_string(index=False))
            print(f"\nMétriques: Rating moy={metrics['avg_rating']:.2f}, "
                  f"Similarité moy={metrics['avg_similarity']:.3f}, "
                  f"Diversité genres={metrics['genre_diversity']}\n")
    
    return pd.DataFrame(all_results)

# %%
def aggregate_results(results_df):
    """
    Agrège les résultats de tous les tests pour comparer les modèles.
    
    Args:
        results_df: DataFrame des résultats individuels
        
    Returns:
        DataFrame avec les moyennes par modèle
    """
    agg = results_df.groupby('model').agg({
        'avg_rating': 'mean',
        'avg_similarity': 'mean',
        'avg_score': 'mean',
        'genre_diversity': 'mean',
        'year_std': 'mean',
        'avg_box_office': 'mean'
    }).round(3)
    
    return agg

# %%
def main():
    """
    Fonction principale pour exécuter la comparaison complète.
    """
    print("Chargement des données...")
    data = load_and_prepare_data("C:/Users/remis/Documents/M1/cine5/python/data/DATASETULTIME.csv")
    
    # Choisir des films de test variés
    test_indices = [4, 10, 50, 100, 500]  # Vous pouvez changer ces indices
    
    print(f"Nombre total de films: {len(data)}")
    print(f"Films de test: {len(test_indices)}")
    
    # Préparer les bag of words pour différentes configurations
    print("\nPréparation des bag of words...")
    bow_simple = create_bag_of_words(data, include_plot=False, genre_weight=1)
    bow_with_plot = create_bag_of_words(data, include_plot=True, genre_weight=1)
    bow_weighted = create_bag_of_words(data, include_plot=False, genre_weight=3)
    
    # Vectorisation TF-IDF
    print("Vectorisation TF-IDF...")
    vectorizer_simple = TfidfVectorizer(max_features=5000, stop_words='english')
    tfidf_simple = vectorizer_simple.fit_transform(bow_simple)
    
    vectorizer_plot = TfidfVectorizer(max_features=5000, stop_words='english')
    tfidf_plot = vectorizer_plot.fit_transform(bow_with_plot)
    
    vectorizer_weighted = TfidfVectorizer(max_features=5000, stop_words='english')
    tfidf_weighted = vectorizer_weighted.fit_transform(bow_weighted)
    
    # Configuration des modèles
    models_config = {}
    
    for test_idx in test_indices:
        models_config = {
            "1_Content_Pure": {
                'function': model_content_pure,
                'params': {
                    'query_idx': test_idx,
                    'tfidf_matrix': tfidf_simple,
                    'data': data,
                    'top_k': 5
                }
            },
            "2_Hybrid_Rating": {
                'function': model_hybrid_rating,
                'params': {
                    'query_idx': test_idx,
                    'tfidf_matrix': tfidf_simple,
                    'data': data,
                    'top_k': 5,
                    'alpha': 0.2
                }
            },
            "3_Hybrid_Full": {
                'function': model_hybrid_full,
                'params': {
                    'query_idx': test_idx,
                    'tfidf_matrix': tfidf_simple,
                    'data': data,
                    'top_k': 5,
                    'alpha': 0.2,
                    'beta': 0.1
                }
            },
            "4_Content_Plot": {
                'function': model_content_pure,
                'params': {
                    'query_idx': test_idx,
                    'tfidf_matrix': tfidf_plot,
                    'data': data,
                    'top_k': 5
                }
            },
            "5_Weighted_Genres": {
                'function': model_hybrid_rating,
                'params': {
                    'query_idx': test_idx,
                    'tfidf_matrix': tfidf_weighted,
                    'data': data,
                    'top_k': 5,
                    'alpha': 0.2
                }
            },
            "6_KNN": {
                'function': model_knn,
                'params': {
                    'query_idx': test_idx,
                    'data': data,
                    'top_k': 5
                }
            }
        }
        
        # Comparer les modèles
        print("\n" + "="*80)
        print("COMPARAISON DES MODÈLES")
        print("="*80)
        
        results = compare_models(data, [test_idx], models_config)
    
    # Agréger et afficher les résultats
    print("\n" + "="*80)
    print("RÉSULTATS AGRÉGÉS (Moyennes sur tous les tests)")
    print("="*80)
    aggregated = aggregate_results(results)
    print(aggregated.to_string())
    
    # Sauvegarder les résultats
    results.to_csv("model_comparison_detailed.csv", index=False)
    aggregated.to_csv("model_comparison_aggregated.csv")
    
    print("\n✅ Comparaison terminée!")
    print("📊 Résultats sauvegardés dans 'model_comparison_detailed.csv' et 'model_comparison_aggregated.csv'")
    
    return results, aggregated

# %%
results, aggregated = main()
# Out:
# Chargement des données...
# Nombre total de films: 5540
# Films de test: 5
#
# Préparation des bag of words...
# Vectorisation TF-IDF...
#
# ================================================================================
# COMPARAISON DES MODÈLES
# ================================================================================
#
# ================================================================================
# FILM DE TEST: The Lord of the Rings: The Two Towers (2002)
# Genre: Action | Rating: 8.8
# ================================================================================
#
# --- 1_Content_Pure ---
#                                       Movie_Title  Year main_genre  Rating    score
#     The Lord of the Rings: The Return of the King  2003     Action     9.0 0.922897
# The Lord of the Rings: The Fellowship of the Ring  2001     Action     8.8 0.789790
#                             The Lord of the Rings  1978  Animation     6.2 0.272297
#                                         Apt Pupil  1998      Crime     6.7 0.243883
#                                          Daylight  1996     Action     5.9 0.225332
#
# Métriques: Rating moy=7.32, Similarité moy=0.491, Diversité genres=3
#
# --- 2_Hybrid_Rating ---
#                                       Movie_Title  Year main_genre  Rating    score
#     The Lord of the Rings: The Return of the King  2003     Action     9.0 0.931089
# The Lord of the Rings: The Fellowship of the Ring  2001     Action     8.8 0.819784
#                                        Green Book  2018  Biography     8.2 0.351333
#                             The Lord of the Rings  1978  Animation     6.2 0.343139
#                                         Apt Pupil  1998      Crime     6.7 0.332456
#
# Métriques: Rating moy=7.78, Similarité moy=0.490, Diversité genres=4
#
# --- 3_Hybrid_Full ---
#                                       Movie_Title  Year main_genre  Rating    score
#     The Lord of the Rings: The Return of the King  2003     Action     9.0 0.838799
# The Lord of the Rings: The Fellowship of the Ring  2001     Action     8.8 0.740805
#                                        Green Book  2018  Biography     8.2 0.329103
#                             The Lord of the Rings  1978  Animation     6.2 0.315909
#                             A History of Violence  2005     Action     7.4 0.308685
#
# Métriques: Rating moy=7.92, Similarité moy=0.486, Diversité genres=3
#
# --- 4_Content_Plot ---
#                                       Movie_Title  Year main_genre  Rating    score
#     The Lord of the Rings: The Return of the King  2003     Action     9.0 0.626969
# The Lord of the Rings: The Fellowship of the Ring  2001     Action     8.8 0.461697
#                                          The Ring  2002     Horror     7.1 0.427456
#                                          Daylight  1996     Action     5.9 0.189350
#                                         Apt Pupil  1998      Crime     6.7 0.178635
#
# Métriques: Rating moy=7.50, Similarité moy=0.377, Diversité genres=3
#
# --- 5_Weighted_Genres ---
#                                       Movie_Title  Year main_genre  Rating    score
#     The Lord of the Rings: The Return of the King  2003     Action     9.0 0.937497
# The Lord of the Rings: The Fellowship of the Ring  2001     Action     8.8 0.838532
#                                 Kingdom of Heaven  2005     Action     7.2 0.389385
#                                    Thirteen Lives  2022     Action     7.8 0.387426
#                             A History of Violence  2005     Action     7.4 0.380667
#
# Métriques: Rating moy=8.04, Similarité moy=0.521, Diversité genres=1
#
# --- 6_KNN ---
#                                       Movie_Title  Year main_genre  Rating    score
# The Lord of the Rings: The Fellowship of the Ring  2001     Action     8.8 0.951232
#     The Lord of the Rings: The Return of the King  2003     Action     9.0 0.342752
#                                 Avengers: Endgame  2019     Action     8.4 0.280663
#                                         Gladiator  2000     Action     8.5 0.266731
#                                      The Revenant  2015     Action     8.0 0.000000
#
# Métriques: Rating moy=8.54, Similarité moy=0.368, Diversité genres=1
#
#
# ================================================================================
# COMPARAISON DES MODÈLES
# ================================================================================
#
# ================================================================================
# FILM DE TEST: Seppuku (1962)
# Genre: Action | Rating: 8.6
# ================================================================================
#
# --- 1_Content_Pure ---
#       Movie_Title  Year main_genre  Rating    score
#           Sanjuro  1962     Action     8.0 0.659542
#               Ran  1985     Action     8.2 0.621304
# Tengoku to jigoku  1963      Crime     8.4 0.526666
#           Yôjinbô  1961     Action     8.2 0.513907
#         Kagemusha  1980      Drama     7.9 0.446662
#
# Métriques: Rating moy=8.14, Similarité moy=0.554, Diversité genres=3
#
# --- 2_Hybrid_Rating ---
#       Movie_Title  Year main_genre  Rating    score
#           Sanjuro  1962     Action     8.0 0.696308
#               Ran  1985     Action     8.2 0.670537
# Tengoku to jigoku  1963      Crime     8.4 0.599646
#           Yôjinbô  1961     Action     8.2 0.584619
#         Kagemusha  1980      Drama     7.9 0.523594
#
# Métriques: Rating moy=8.14, Similarité moy=0.554, Diversité genres=3
#
# --- 3_Hybrid_Full ---
#       Movie_Title  Year main_genre  Rating    score
#           Sanjuro  1962     Action     8.0 0.630354
#               Ran  1985     Action     8.2 0.608407
# Tengoku to jigoku  1963      Crime     8.4 0.546980
#           Yôjinbô  1961     Action     8.2 0.533229
#         Kagemusha  1980      Drama     7.9 0.478928
#
# Métriques: Rating moy=8.14, Similarité moy=0.554, Diversité genres=3
#
# --- 4_Content_Plot ---
#       Movie_Title  Year main_genre  Rating    score
#               Ran  1985     Action     8.2 0.325479
# Tengoku to jigoku  1963      Crime     8.4 0.280905
#           Yôjinbô  1961     Action     8.2 0.279964
#           Sanjuro  1962     Action     8.0 0.275781
#         Kagemusha  1980      Drama     7.9 0.263701
#
# Métriques: Rating moy=8.14, Similarité moy=0.285, Diversité genres=3
#
# --- 5_Weighted_Genres ---
#       Movie_Title  Year main_genre  Rating    score
#           Sanjuro  1962     Action     8.0 0.692087
#               Ran  1985     Action     8.2 0.649557
#           Yôjinbô  1961     Action     8.2 0.602648
# Tengoku to jigoku  1963      Crime     8.4 0.587810
#         Kagemusha  1980      Drama     7.9 0.463448
#
# Métriques: Rating moy=8.14, Similarité moy=0.534, Diversité genres=3
#
# --- 6_KNN ---
#        Movie_Title  Year main_genre  Rating    score
#          Backdraft  1991     Action     6.7 0.273896
#           Oldeuboi  2003     Action     8.4 0.212882
# Courage Under Fire  1996     Action     6.6 0.171188
#           Watchmen  2009     Action     7.6 0.097531
#        Source Code  2011     Action     7.5 0.000000
#
# Métriques: Rating moy=7.36, Similarité moy=0.151, Diversité genres=1
#
#
# ================================================================================
# COMPARAISON DES MODÈLES
# ================================================================================
#
# ================================================================================
# FILM DE TEST: Indiana Jones and the Last Crusade (1989)
# Genre: Action | Rating: 8.2
# ================================================================================
#
# --- 1_Content_Pure ---
#                                        Movie_Title  Year main_genre  Rating    score
#               Indiana Jones and the Temple of Doom  1984     Action     7.5 0.523076
# Indiana Jones and the Kingdom of the Crystal Skull  2008     Action     6.2 0.492301
#                            Raiders of the Lost Ark  1981     Action     8.4 0.351244
#                                        Thunderball  1965     Action     6.9 0.299535
#                                You Only Live Twice  1967     Action     6.8 0.256951
#
# Métriques: Rating moy=7.16, Similarité moy=0.385, Diversité genres=1
#
# --- 2_Hybrid_Rating ---
#                                        Movie_Title  Year main_genre  Rating    score
#               Indiana Jones and the Temple of Doom  1984     Action     7.5 0.575087
# Indiana Jones and the Kingdom of the Crystal Skull  2008     Action     6.2 0.519142
#                            Raiders of the Lost Ark  1981     Action     8.4 0.459309
#                                        Thunderball  1965     Action     6.9 0.381796
#                                       The Fugitive  1993     Action     7.8 0.353715
#
# Métriques: Rating moy=7.36, Similarité moy=0.381, Diversité genres=1
#
# --- 3_Hybrid_Full ---
#                                        Movie_Title  Year main_genre  Rating    score
#               Indiana Jones and the Temple of Doom  1984     Action     7.5 0.522779
# Indiana Jones and the Kingdom of the Crystal Skull  2008     Action     6.2 0.469912
#                            Raiders of the Lost Ark  1981     Action     8.4 0.424184
#                                        Thunderball  1965     Action     6.9 0.351843
#                                       The Fugitive  1993     Action     7.8 0.329983
#
# Métriques: Rating moy=7.36, Similarité moy=0.381, Diversité genres=1
#
# --- 4_Content_Plot ---
#                                        Movie_Title  Year main_genre  Rating    score
#               Indiana Jones and the Temple of Doom  1984     Action     7.5 0.492991
# Indiana Jones and the Kingdom of the Crystal Skull  2008     Action     6.2 0.420921
#                            Raiders of the Lost Ark  1981     Action     8.4 0.390655
#                 Close Encounters of the Third Kind  1977      Drama     7.6 0.179021
#                               Bridget Jones's Baby  2016     Comedy     6.5 0.141768
#
# Métriques: Rating moy=7.24, Similarité moy=0.325, Diversité genres=3
#
# --- 5_Weighted_Genres ---
#                                        Movie_Title  Year main_genre  Rating    score
#               Indiana Jones and the Temple of Doom  1984     Action     7.5 0.620262
# Indiana Jones and the Kingdom of the Crystal Skull  2008     Action     6.2 0.564328
#                            Raiders of the Lost Ark  1981     Action     8.4 0.526835
#                                        Thunderball  1965     Action     6.9 0.466831
#                                         Goldfinger  1964     Action     7.7 0.436494
#
# Métriques: Rating moy=7.34, Similarité moy=0.463, Diversité genres=1
#
# --- 6_KNN ---
#                                        Movie_Title  Year main_genre  Rating    score
#                                             Batman  1989     Action     7.5 0.743684
#                            Raiders of the Lost Ark  1981     Action     8.4 0.735479
#               Indiana Jones and the Temple of Doom  1984     Action     7.5 0.688750
# Indiana Jones and the Kingdom of the Crystal Skull  2008     Action     6.2 0.162055
#                                          Uncharted  2022     Action     6.3 0.000000
#
# Métriques: Rating moy=7.18, Similarité moy=0.466, Diversité genres=1
#
#
# ================================================================================
# COMPARAISON DES MODÈLES
# ================================================================================
#
# ================================================================================
# FILM DE TEST: Minnal Murali (2021)
# Genre: Action | Rating: 7.9
# ================================================================================
#
# --- 1_Content_Pure ---
# Movie_Title  Year main_genre  Rating    score
#  Stalingrad  1993      Drama     7.5 0.373183
#   Thuppakki  2012     Action     8.0 0.326779
#        Druk  2020     Comedy     7.7 0.296970
#  Abominable  2019  Animation     7.0 0.290803
#     Don Jon  2013     Comedy     6.5 0.288850
#
# Métriques: Rating moy=7.34, Similarité moy=0.315, Diversité genres=4
#
# --- 2_Hybrid_Rating ---
# Movie_Title  Year main_genre  Rating    score
#  Stalingrad  1993      Drama     7.5 0.455173
#   Thuppakki  2012     Action     8.0 0.430098
#        Druk  2020     Comedy     7.7 0.399022
#      Festen  1998      Drama     8.1 0.397120
#      Jagten  2012      Drama     8.3 0.393341
#
# Métriques: Rating moy=7.92, Similarité moy=0.310, Diversité genres=3
#
# --- 3_Hybrid_Full ---
# Movie_Title  Year main_genre  Rating    score
#  Stalingrad  1993      Drama     7.5 0.417854
#   Thuppakki  2012     Action     8.0 0.397420
#        Druk  2020     Comedy     7.7 0.369325
#      Festen  1998      Drama     8.1 0.368866
#      Jagten  2012      Drama     8.3 0.366161
#
# Métriques: Rating moy=7.92, Similarité moy=0.310, Diversité genres=3
#
# --- 4_Content_Plot ---
#                              Movie_Title  Year main_genre  Rating    score
#                                  Shazam!  2019     Action     7.0 0.219728
#                   The Amazing Spider-Man  2012     Action     6.9 0.198379
#                               Abominable  2019  Animation     7.0 0.183020
# Captain Underpants: The First Epic Movie  2017  Animation     6.2 0.154646
#                         Midnight Special  2016      Drama     6.6 0.153190
#
# Métriques: Rating moy=6.74, Similarité moy=0.182, Diversité genres=3
#
# --- 5_Weighted_Genres ---
#           Movie_Title  Year main_genre  Rating    score
#             Thuppakki  2012     Action     8.0 0.504894
#                Sholay  1975     Action     8.1 0.501482
# Letters from Iwo Jima  2006     Action     7.9 0.479844
#            Apocalypto  2006     Action     7.8 0.473872
#          Karthikeya 2  2022     Action     8.0 0.471171
#
# Métriques: Rating moy=7.96, Similarité moy=0.398, Diversité genres=1
#
# --- 6_KNN ---
#                       Movie_Title  Year main_genre  Rating    score
#                 Bajrangi Bhaijaan  2015     Action     8.1 0.656135
# Everything Everywhere All at Once  2022     Action     8.1 0.360018
#    Guardians of the Galaxy Vol. 2  2017     Action     7.6 0.226778
#                    Thor: Ragnarok  2017     Action     7.9 0.069192
#                 The Suicide Squad  2021     Action     7.2 0.000000
#
# Métriques: Rating moy=7.78, Similarité moy=0.262, Diversité genres=1
#
#
# ================================================================================
# COMPARAISON DES MODÈLES
# ================================================================================
#
# ================================================================================
# FILM DE TEST: Tom yum goong (2005)
# Genre: Action | Rating: 7.0
# ================================================================================
#
# --- 1_Content_Pure ---
#    Movie_Title  Year main_genre  Rating    score
#        Ong-bak  2003     Action     7.1 0.637131
#      Ong Bak 2  2008     Action     6.2 0.630284
#  The Condemned  2007     Action     6.0 0.363625
# Monster Hunter  2020     Action     5.2 0.307234
#      Seungriho  2021     Action     6.5 0.255851
#
# Métriques: Rating moy=6.20, Similarité moy=0.439, Diversité genres=1
#
# --- 2_Hybrid_Rating ---
#    Movie_Title  Year main_genre  Rating    score
#        Ong-bak  2003     Action     7.1 0.656693
#      Ong Bak 2  2008     Action     6.2 0.629529
#  The Condemned  2007     Action     6.0 0.411382
# Monster Hunter  2020     Action     5.2 0.346992
#      Seungriho  2021     Action     6.5 0.337211
#
# Métriques: Rating moy=6.20, Similarité moy=0.439, Diversité genres=1
#
# --- 3_Hybrid_Full ---
#    Movie_Title  Year main_genre  Rating    score
#        Ong-bak  2003     Action     7.1 0.592980
#      Ong Bak 2  2008     Action     6.2 0.566500
#  The Condemned  2007     Action     6.0 0.375020
# Monster Hunter  2020     Action     5.2 0.316268
#      Seungriho  2021     Action     6.5 0.311626
#
# Métriques: Rating moy=6.20, Similarité moy=0.439, Diversité genres=1
#
# --- 4_Content_Plot ---
#                     Movie_Title  Year main_genre  Rating    score
#                         Ong-bak  2003     Action     7.1 0.228999
# Man cheng jin dai huang jin jia  2006     Action     7.0 0.161711
#           From Russia with Love  1963     Action     7.4 0.158579
#                      The Jackal  1997     Action     6.4 0.144970
#                     The Accused  1988      Crime     7.1 0.139687
#
# Métriques: Rating moy=7.00, Similarité moy=0.167, Diversité genres=2
#
# --- 5_Weighted_Genres ---
#   Movie_Title  Year main_genre  Rating    score
#       Ong-bak  2003     Action     7.1 0.681443
#     Ong Bak 2  2008     Action     6.2 0.653964
# The Condemned  2007     Action     6.0 0.484518
#   Man on Fire  2004     Action     7.7 0.395406
#  Ölümlü Dünya  2018     Action     7.6 0.390176
#
# Métriques: Rating moy=6.92, Similarité moy=0.473, Diversité genres=1
#
# --- 6_KNN ---
#      Movie_Title  Year main_genre  Rating    score
#    Four Brothers  2005     Action     6.8 0.372902
#          Traitor  2008     Action     6.9 0.312897
#      Harsh Times  2005     Action     6.8 0.152326
#        Unleashed  2005     Action     7.0 0.004317
# We Own the Night  2007     Action     6.8 0.000000
#
# Métriques: Rating moy=6.86, Similarité moy=0.168, Diversité genres=1
#
#
# ================================================================================
# RÉSULTATS AGRÉGÉS (Moyennes sur tous les tests)
# ================================================================================
#                    avg_rating  avg_similarity  avg_score  genre_diversity  year_std  avg_box_office
# model
# 1_Content_Pure           6.20           0.439      0.439              1.0     8.167             0.0
# 2_Hybrid_Rating          6.20           0.439      0.476              1.0     8.167             0.0
# 3_Hybrid_Full            6.20           0.439      0.432              1.0     8.167             0.0
# 4_Content_Plot           7.00           0.167      0.167              2.0    17.300             0.0
# 5_Weighted_Genres        6.92           0.473      0.521              1.0     5.958             0.0
# 6_KNN                    6.86           0.168      0.168              1.0     1.414             0.0
#
# ✅ Comparaison terminée!
# 📊 Résultats sauvegardés dans 'model_comparison_detailed.csv' et 'model_comparison_aggregated.csv'
